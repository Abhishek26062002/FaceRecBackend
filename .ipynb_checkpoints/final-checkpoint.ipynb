# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import tensorflow as tf
model = tf.keras.applications.MobileNetV3Small(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet'
)

# %%
import os
path = "Images"
images = []
labels = []

for j in os.listdir(path):
    img = tf.keras.preprocessing.image.load_img(os.path.join(path, j), target_size=(224, 224))
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)
    images.append(img_array)
    labels.append(j.split(".")[0])

# %%
# read and view the images
import matplotlib.pyplot as plt 
import numpy as np
for i in range(4):
    plt.imshow(np.array(images[i][0], dtype='uint8'))
    plt.show()

# %%
images[0].shape
# Out:
# TensorShape([1, 224, 224, 3])

# %%
augmented_images[0].shape
# Out:
# (1, 224, 224, 3)

# %%
labels
# Out:
# ['Bharath', 'jahnavi', 'sathwika', 'Sravan']

# %%
output_lables = [[0],[1],[2],[3]]

# %%
df = tf.data.Dataset.from_tensor_slices((images, output_lables))

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = df.prefetch(buffer_size=AUTOTUNE)
test_dataset = df.prefetch(buffer_size=AUTOTUNE)

# %%
image_batch, label_batch = next(iter(train_dataset))
feature_batch = model(image_batch)
print(feature_batch.shape)
# Out:
# (1, 7, 7, 576)

# %%
# view the image batch
plt.imshow(np.array(image_batch[0], dtype='uint8'))

# %%
label_batch
# Out:
# <tf.Tensor: shape=(1,), dtype=int32, numpy=array([0])>

# %%
image_batch.shape
# Out:
# TensorShape([1, 224, 224, 3])

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (1, 576)

# %%
prediction_layer = tf.keras.layers.Dense(4, activation='softmax')
prediction_batch = prediction_layer(feature_batch_average)
print(prediction_batch.shape)
# Out:
# (1, 4)

# %%
model.trainable = True
x = model
x = global_average_layer(model.output)
x = tf.keras.layers.Dropout(0.2)(x)
x = prediction_layer(x)
model = tf.keras.Model(model.input, x)

# %%
len(model.trainable_variables)
# Out:
# 140

# %%
tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %%
base_learning_rate = 0.0001

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),  # Correct name
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy(name='accuracy')]  # Correct metric
)

# %%
epochs = 20
history = model.fit(train_dataset,
                    epochs=epochs,
                    validation_data=test_dataset)
# Out:
# Epoch 1/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 30s 506ms/step - accuracy: 0.1000 - loss: 2.4043 - val_accuracy: 0.0000e+00 - val_loss: 2.0064
# Epoch 2/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7333 - loss: 1.0079 - val_accuracy: 0.0000e+00 - val_loss: 2.0108
# Epoch 3/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.8667 - val_accuracy: 0.0000e+00 - val_loss: 2.0126
# Epoch 4/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.6495 - val_accuracy: 0.0000e+00 - val_loss: 2.0039
# Epoch 5/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.5727 - val_accuracy: 0.0000e+00 - val_loss: 1.9954
# Epoch 6/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.3896 - val_accuracy: 0.0000e+00 - val_loss: 1.9869
# Epoch 7/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.3638 - val_accuracy: 0.0000e+00 - val_loss: 1.9754
# Epoch 8/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.2098 - val_accuracy: 0.0000e+00 - val_loss: 1.9648
# Epoch 9/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.2977 - val_accuracy: 0.0000e+00 - val_loss: 1.9535
# Epoch 10/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.1321 - val_accuracy: 0.0000e+00 - val_loss: 1.9418
# Epoch 11/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.1520 - val_accuracy: 0.0000e+00 - val_loss: 1.9307
# Epoch 12/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.1567 - val_accuracy: 0.0000e+00 - val_loss: 1.9219
# Epoch 13/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.2428 - val_accuracy: 0.0000e+00 - val_loss: 1.9174
# Epoch 14/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.1749 - val_accuracy: 0.0000e+00 - val_loss: 1.9155
# Epoch 15/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.1661 - val_accuracy: 0.0000e+00 - val_loss: 1.9133
# Epoch 16/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 0.0720 - val_accuracy: 0.0000e+00 - val_loss: 1.9097
# Epoch 17/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 0.0768 - val_accuracy: 0.0000e+00 - val_loss: 1.9063
# Epoch 18/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 0.1256 - val_accuracy: 0.0000e+00 - val_loss: 1.9022
# Epoch 19/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 1.0000 - loss: 0.0956 - val_accuracy: 0.0000e+00 - val_loss: 1.8975
# Epoch 20/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 1.0000 - loss: 0.0765 - val_accuracy: 0.0000e+00 - val_loss: 1.8930

# %%
model.save("face-net-fine-tunes.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
ind = np.argmax(model.predict(images[1]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step

# %%
labels[ind]
# Out:
# 'Bharath'

# %%
img = tf.keras.preprocessing.image.load_img(r"C:\Users\abhishek\Desktop\Abhishek.jpg", target_size=(224, 224))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

# %%
new = np.argmax(model.predict(img_array))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step

# %%
labels[new]
# Out:
# 'jahnavi'
